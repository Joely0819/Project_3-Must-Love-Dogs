# %%
#import dependencies
import os
import csv
import pandas as pd

# %%
# File to Load
file_to_load = "Resources/dog_breed_characteristics.csv"
# Read Purchasing File and store into Pandas data frame
dog_characteristics = pd.read_csv(file_to_load, encoding="utf-8")
dog_characteristics
# Out:
#                            BreedName       AltBreedName        Group1  \
# 0                      Affenpinscher                NaN           Toy
# 1                       Afghan Hound                NaN      Sporting
# 2                African Hunting Dog                NaN           NaN
# 3                   Airedale Terrier           Airedale       Terrier
# 4                             Akbash                NaN       Working
# ..                               ...                ...           ...
# 245               Wirehaired Terrier                NaN       Terrier
# 246  Xoloitzcuintle/Mexican Hairless   Mexican Hairless  Non Sporting
# 247        Yellow Labrador Retriever                NaN      Sporting
# 248         Yorkshire Terrier Yorkie  Yorkshire Terrier           Toy
# 249                      Mixed Breed                NaN           NaN
#
#         Group2  MaleWtKg                                         Temperment  \
# 0    Companion       4.0  Active, Adventurous, Curious, Fun-loving, Play...
# 1        Sight      28.0     Aloof, Clownish, Dignified, Happy, Independent
# 2          NaN      23.0                                               Wild
# 3      Terrier      26.0  Alert, Confident, Courageous, Friendly, Intell...
# 4     Guardian      53.0  Affectionate, Alert, Courageous, Independent, ...
# ..         ...       ...                                                ...
# 245    Terrier       7.0  Alert, Bold, Fearless, Friendly, Keen, Quick, ...
# 246      Sight      11.0  Aleret, Calm, Cheerful, Companionable, Loyal, ...
# 247        Gun      32.0  Affectionate, Alert, Cheerful, Energetic, Frie...
# 248  Companion       3.0  Alert, Courageous, Energetic, Independent, Int...
# 249        NaN       NaN                                                NaN
#
#      AvgPupPrice  Intelligence  Watchdog  MalaysiaGuardedDog  \
# 0         1000.0          37.0       1.0                 NaN
# 1         2250.0          79.0       1.0                 NaN
# 2            NaN           NaN       NaN                 NaN
# 3          700.0          29.0       4.0                 NaN
# 4          600.0           NaN       5.0                 NaN
# ..           ...           ...       ...                 ...
# 245        900.0          51.0       3.0                 NaN
# 246        700.0           NaN       3.0                 NaN
# 247       1500.0           7.0       3.0                 NaN
# 248        800.0          27.0       3.0                 NaN
# 249          NaN           NaN       NaN                 NaN
#
#      MalaysiaProhibitedDog  MalaysiaPopularity  PopularityUS2017
# 0                      NaN                 NaN             147.0
# 1                      NaN                 NaN              93.0
# 2                      NaN                 NaN               NaN
# 3                      NaN                 NaN              55.0
# 4                      NaN                 NaN               NaN
# ..                     ...                 ...               ...
# 245                    NaN                 NaN              99.0
# 246                    NaN                 NaN             143.0
# 247                    NaN                 NaN               1.0
# 248                    NaN                 NaN               9.0
# 249                    NaN                 NaN               NaN
#
# [250 rows x 13 columns]

# %%
 # Remove unecessary columns from the DataFrame and save the new DataFrame
    # Only keep: "BreedName", "Group1", "Temperment", "AvgPupPrice", "PopularityUS2017"

dogs_cleaned_df = dogs_df[["BreedName", "Group1", "Temperment", "AvgPupPrice",
                       "PopularityUS2017"]]

dogs_cleaned_df.head()
# Out:
#              BreedName    Group1  \
# 0        Affenpinscher       Toy
# 1         Afghan Hound  Sporting
# 2  African Hunting Dog       NaN
# 3     Airedale Terrier   Terrier
# 4               Akbash   Working
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    PopularityUS2017
# 0             147.0
# 1              93.0
# 2               NaN
# 3              55.0
# 4               NaN

# %%
# Push the remade DataFrame to a new CSV file
dogs_cleaned_df.to_csv("Output/dog_breed_characteristics_clean.csv",
                  encoding="utf-8", index=False, header=True)
